# %%
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
data = pd.read_csv("https://raw.githubusercontent.com/paulharris171/cs109b-Movie-Prediction-/master/movie_dataframe2.csv?token=AGPPqGyJKmQ_UcrlB-89osC4WAjdQ0_7ks5ZESwrwA%3D%3D")

# %%
data.head()
# Out:
#      director_name       budget  \
# 0      James Bobin  170000000.0
# 1       Jon M. Chu   90000000.0
# 2     Michael Mann   70000000.0
# 3  Joel Schumacher   70000000.0
# 4     Peter Ramsey  145000000.0
#
#                                               genres      actor_1_name  \
# 0                 ['Adventure', 'Family', 'Fantasy']       Johnny Depp
# 1  ['Action', 'Adventure', 'Comedy', 'Crime', 'My...  Daniel Radcliffe
# 2  ['Action', 'Crime', 'Drama', 'Mystery', 'Thril...   Chris Hemsworth
# 3        ['Drama', 'Musical', 'Romance', 'Thriller']     Gerard Butler
# 4    ['Adventure', 'Animation', 'Family', 'Fantasy']      Hugh Jackman
#
#                         movie_title  \
# 0  Alice Through the Looking Glass
# 1                 Now You See Me 2
# 2                         Blackhat
# 3         The Phantom of the Opera
# 4            Rise of the Guardians
#
#                                        plot_keywords content_rating  \
# ...

# %%
# python is reading the list as a single string
data['genres'].values[0]
# Out:
# '['

# %%
#Convert string to list
titles = []
for title in data['genres']:
    titles.append(re.sub("[^\w\-]", " ",  title).split())

# %%
'Adventure' in titles[0]
# Out:
# True

# %% [markdown]
# #### However, you will notice that the genre list for each movie from both databases can have different lengths. This needs to be changed in order to train a model to predict the movie genre. It is up to you to think about possible ways to address this problem and to implement one of them. There is no absolute right answer here. It depends on your interests and which questions you have in mind for the project.

# %%
complete= []
for title in titles:
    for thing in title:
        complete.append(thing)

# %%
complete
# Out:
# ['Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Musical',
#  'Romance',
#  'Thriller',
#  'Adventure',
#  'Animation',
#  'Family',
#  'Fantasy',
#  'Adventure',
#  'Animation',
#  'Family',
#  'Fantasy',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Action',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Thriller',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Documentary',
#  'Drama',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Fantasy',
#  'Horror',
#  'Mystery',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Biography',
#  'Drama',
#  'Music',
#  'Romance',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Sci-Fi',
#  'Horror',
#  'Sci-Fi',
#  'Thriller',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Comedy',
#  'Family',
# ...

# %%
# This is the count of occurances of each genre
Counter(complete)
# Out:
# Counter({'Action': 699,
#          'Adventure': 581,
#          'Animation': 163,
#          'Biography': 98,
#          'Comedy': 631,
#          'Crime': 332,
#          'Documentary': 3,
#          'Drama': 713,
#          'Family': 300,
#          'Fantasy': 343,
#          'History': 82,
#          'Horror': 110,
#          'Music': 40,
#          'Musical': 43,
#          'Mystery': 184,
#          'Romance': 348,
#          'Sci-Fi': 337,
#          'Sport': 70,
#          'Thriller': 599,
#          'War': 85,
#          'Western': 30})

# %%
genres = []
for title in titles:
    if len(title) == 1:
        genres.append(title[0])
    else:
        if 'Horror' in title:
            genres.append('Horror')
            continue
        elif 'Sport' in title:
            genres.append('Sport')
            continue
        elif 'War' in title:
            genres.append('War')
            continue
        elif 'Western' in title:
            genres.append('Western')
            continue
        elif 'Biography' in title: 
            genres.append('Biography')
            continue
        elif 'History' in title or 'Documentary' in title:
            genres.append('History')
            continue
        elif 'Animation' in title:
            genres.append('Animation')
            continue
        elif 'Family' in title:
            genres.append('Family')
            continue
        elif 'Music' in title or 'Musical' in title:
            genres.append('Musical')
            continue
        elif 'Sci-Fi' in title:
            genres.append('Sci-Fi')
            continue
        elif 'Mystery' in title:
            genres.append('Mystery')
            continue
        elif 'Romance' and 'Comedy' in title:
            genres.append('Rom-Com')
            continue
        elif 'Comedy' and 'Action' in title:
            genres.append('Action-Comedy')
            continue
        elif 'Romance' and 'Action' in title:
            genres.append('Action-Romance')
            continue
        elif 'Drama' and 'Action' in title:
            genres.append('Action-Drama')
            continue
        elif 'Thriller' and 'Action' in title:
            genres.append('Action-Thriller')
            continue
        genres.append(title[0])

# %%
Counter(genres)
# Out:
# Counter({'Action': 3,
#          'Action-Comedy': 229,
#          'Adventure': 19,
#          'Animation': 150,
#          'Biography': 65,
#          'Comedy': 43,
#          'Crime': 56,
#          'Documentary': 1,
#          'Drama': 77,
#          'Family': 137,
#          'History': 22,
#          'Horror': 110,
#          'Musical': 28,
#          'Mystery': 104,
#          'Rom-Com': 262,
#          'Sci-Fi': 236,
#          'Sport': 70,
#          'War': 82,
#          'Western': 27})

# %%
data['genre_adjusted'] = genres

# %%
data['genre_adjusted']
# Out:
# 0               Family
# 1              Rom-Com
# 2              Mystery
# 3              Musical
# 4            Animation
# 5            Animation
# 6            Adventure
# 7              Mystery
# 8              Rom-Com
# 9            Biography
# 10             History
# 11               Crime
# 12             Rom-Com
# 13              Horror
# 14             Rom-Com
# 15           Biography
# 16           Animation
# 17              Horror
# 18             Mystery
# 19               Sport
# 20              Comedy
# 21               Drama
# 22             Rom-Com
# 23              Horror
# 24              Sci-Fi
# 25           Adventure
# 26              Sci-Fi
# 27      Action-Romance
# 28              Comedy
# 29              Horror
#              ...
# 1691             Drama
# 1692    Action-Romance
# 1693            Sci-Fi
# 1694            Sci-Fi
# 1695            Horror
# 1696         Adventure
# 1697           Rom-Com
# 1698            Family
# 1699           Rom-Com
# ...

# %%
data.to_csv('movie_dataframe3',sep=',',header=True,index=False)

# %% [markdown]
# Do for all data

# %%
dataframe = pd.read_csv('https://raw.githubusercontent.com/sundeepblue/movie_rating_prediction/master/movie_metadata.csv')

# %%
titles = []
for title in dataframe['genres']:
    titles.append(re.sub("[^\w\-]", " ",  title).split())

complete= []
for title in titles:
    for thing in title:
        complete.append(thing)
        
genres = []
for title in titles:
    if len(title) == 1:
        genres.append(title[0])
    else:
        if 'Horror' in title:
            genres.append('Horror')
            continue
        elif 'Sport' in title:
            genres.append('Sport')
            continue
        elif 'War' in title:
            genres.append('War')
            continue
        elif 'Western' in title:
            genres.append('Western')
            continue
        elif 'Biography' in title: 
            genres.append('Biography')
            continue
        elif 'History' in title or 'Documentary' in title:
            genres.append('History')
            continue
        elif 'Animation' in title:
            genres.append('Animation')
            continue
        elif 'Family' in title:
            genres.append('Family')
            continue
        elif 'Music' in title or 'Musical' in title:
            genres.append('Musical')
            continue
        elif 'Sci-Fi' in title:
            genres.append('Sci-Fi')
            continue
        elif 'Mystery' in title:
            genres.append('Mystery')
            continue
        elif 'Romance' and 'Comedy' in title:
            genres.append('Rom-Com')
            continue
        elif 'Comedy' and 'Action' in title:
            genres.append('Action-Comedy')
            continue
        elif 'Romance' and 'Action' in title:
            genres.append('Action-Romance')
            continue
        elif 'Drama' and 'Action' in title:
            genres.append('Action-Drama')
            continue
        elif 'Thriller' and 'Action' in title:
            genres.append('Action-Thriller')
            continue
        genres.append(title[0])

# %%
df1 = dataframe[['director_name','budget','genres','actor_1_name','movie_title','plot_keywords','content_rating']]

for i in range(0,len(df1)):
    df1['genres'].iloc[i] = df1['genres'].iloc[i].split('|')
# Out:
# C:\Users\Excaliburxiv\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\indexing.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Excaliburxiv\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1['genre_adjusted'] = genres
# Out:
# C:\Users\Excaliburxiv\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2 = df1[df1['plot_keywords'].notnull()]

# %%
len(df2)
# Out:
# 4890

# %%
for i in range(0,len(df2)):
    df2['plot_keywords'].iloc[i] = df2['plot_keywords'].iloc[i].split('|')
# Out:
# C:\Users\Excaliburxiv\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
keywords
# Out:
# array([['avatar', 'future', 'marine', 'native', 'paraplegic'],
#        ['goddess', 'marriage ceremony', 'marriage proposal', 'pirate', 'singapore'],
#        ['bomb', 'espionage', 'sequel', 'spy', 'terrorist'], ...,
#        ['fraud', 'postal worker', 'prison', 'theft', 'trial'],
#        ['cult', 'fbi', 'hideout', 'prison escape', 'serial killer'],
#        ['actress name in title', 'crush', 'date', 'four word title', 'video camera']], dtype=object)

# %%
keywords = df2['plot_keywords'].values
actors = df2['actor_1_name'].values
directors = df2['director_name'].values

# %%
for i in range(len(actors)):
    keywords[i].insert(0,actors[i])
    keywords[i].insert(0,directors[i])

# %%
df2['all_keywords'] =keywords
# Out:
# C:\Users\Excaliburxiv\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2.head()
# Out:
#        director_name       budget                                genres  \
# 0      James Cameron  237000000.0  [Action, Adventure, Fantasy, Sci-Fi]
# 1     Gore Verbinski  300000000.0          [Action, Adventure, Fantasy]
# 2         Sam Mendes  245000000.0         [Action, Adventure, Thriller]
# 3  Christopher Nolan  250000000.0                    [Action, Thriller]
# 5     Andrew Stanton  263700000.0           [Action, Adventure, Sci-Fi]
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
# 3        Tom Hardy                     The Dark Knight Rises
# 5     Daryl Sabara                               John Carter
#
#                                        plot_keywords content_rating  \
# 0  [James Cameron, CCH Pounder, avatar, future, m...          PG-13
# ...

# %%
df2.to_csv('complete_movie_dataframe.csv',sep=',',header=True,index=False)

# %%
import matplotlib.pyplot as plt

# %%
Counter(complete)
# Out:
# Counter({'Action': 1153,
#          'Adventure': 923,
#          'Animation': 242,
#          'Biography': 293,
#          'Comedy': 1872,
#          'Crime': 889,
#          'Documentary': 121,
#          'Drama': 2594,
#          'Family': 546,
#          'Fantasy': 610,
#          'Film-Noir': 6,
#          'Game-Show': 1,
#          'History': 207,
#          'Horror': 565,
#          'Music': 214,
#          'Musical': 132,
#          'Mystery': 500,
#          'News': 3,
#          'Reality-TV': 2,
#          'Romance': 1107,
#          'Sci-Fi': 616,
#          'Short': 5,
#          'Sport': 182,
#          'Thriller': 1411,
#          'War': 213,
#          'Western': 97})

# %%
#Already ran
#keywords = data['plot_keywords'].values
#actors = data['actor_1_name'].values
#directors = data['director_name'].values
#keywords_list = []
#for word in keywords:
#    keywords_list.append(re.sub("[^\w\-]", " ",  word).split())

#for i in range(len(actors)):
#    keywords_list[i].insert(0,actors[i])
#    keywords_list[i].insert(0,directors[i])

#data['all_keywords'] =keywords_list
